# %% [markdown]
# # QUESTION 1

# %%
import matplotlib.pyplot as ply

# %% [markdown]
# Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy.
# 5 plots are
# plot, bar, scatter, histogram, boxplot

# %% [markdown]
# # QUESTION 2

# %% [markdown]
# # scatter plot id a plot where are values are scattered and are not joined by any lines.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
ply.scatter(x,y)
ply.ylabel("this is y axis")
ply.title("Scatter plot")
ply.xlabel("this is x axis")

# %% [markdown]
# # QUESTION 3

# %% [markdown]
# With the subplot() function you can draw multiple plots in one figure:

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(1, 4, 1)
plt.plot(x1,y1)
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(1, 4, 2)
plt.plot(x2,y2)
x3 = np.array([0, 1, 2, 3, 4, 5])
y3= np.array([10, 20, 30, 40, 50, 60])
plt.subplot(1, 4, 3)
plt.plot(x3,y3)
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(1, 4, 4)
plt.plot(x4,y4)
plt.show()

# %% [markdown]
# The subplot() function takes three arguments that describes the layout of the figure. The layout is organized in rows and columns, which are represented by the first and second argument. The third argument represents the index of the current plot.

# %% [markdown]
# # QUESTION 4

# %% [markdown]
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically. A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # QUESTION 5

# %% [markdown]
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data = [box1, box2]

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb779366380>,
#   <matplotlib.lines.Line2D at 0x7fb779366620>,
#   <matplotlib.lines.Line2D at 0x7fb77977a2f0>,
#   <matplotlib.lines.Line2D at 0x7fb77977a0e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7793668c0>,
#   <matplotlib.lines.Line2D at 0x7fb7798deda0>,
#   <matplotlib.lines.Line2D at 0x7fb77977af50>,
#   <matplotlib.lines.Line2D at 0x7fb779626770>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7793660e0>,
#   <matplotlib.lines.Line2D at 0x7fb779779870>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7798dfeb0>,
#   <matplotlib.lines.Line2D at 0x7fb7796279a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7798debc0>,
#   <matplotlib.lines.Line2D at 0x7fb7796442e0>],
#  'means': []}
